# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
berlin_set = pd.read_csv("berlin.csv")
frankfurt_set = pd.read_csv("frankfurt.csv")

# %%
print(berlin_set.columns)
print(frankfurt_set.columns)
# Out:
# Index(['day', 'time', 'b_number', 'city', 'trip_duration', 'orig_lat',
#        'orig_lng', 'dest_lat', 'dest_lng'],
#       dtype='object')
# Index(['day', 'time', 'b_number', 'city', 'trip_duration', 'orig_lat',
#        'orig_lng', 'dest_lat', 'dest_lng'],
#       dtype='object')

# %%
berlin_set.head(5)
# Out:
#           day      time  b_number    city              trip_duration  \
# 0  2019-02-16  14:53:00     13001  berlin  0 days 00:21:00.000000000
# 1  2019-02-16  17:22:00     13001  berlin  0 days 00:27:00.000000000
# 2  2019-02-16  23:29:00     13001  berlin  0 days 00:22:00.000000000
# 3  2019-02-18  17:49:00     13001  berlin  0 days 00:15:00.000000000
# 4  2019-02-19  13:08:00     13001  berlin  0 days 00:09:00.000000000
#
#     orig_lat   orig_lng   dest_lat   dest_lng
# 0  52.505076  13.414721  52.534591  13.452043
# 1  52.534591  13.452043  52.504621  13.415686
# 2  52.504621  13.415686  52.528998  13.456997
# 3  52.528998  13.456997  52.536231  13.432285
# 4  52.536231  13.432285  52.543311  13.441611

# %%
frankfurt_set.head(5)
# Out:
#           day      time  b_number       city              trip_duration  \
# 0  2019-06-25  21:51:00     11420  frankfurt  0 days 00:07:00.000000000
# 1  2019-06-26  06:33:00     11420  frankfurt  0 days 00:14:00.000000000
# 2  2019-06-27  13:20:00     11420  frankfurt  0 days 00:07:00.000000000
# 3  2019-06-27  13:30:00     11420  frankfurt  0 days 00:04:00.000000000
# 4  2019-06-27  13:59:00     11420  frankfurt  0 days 00:09:00.000000000
#
#     orig_lat  orig_lng   dest_lat  dest_lng
# 0  49.991072  8.412515  49.984942  8.409474
# 1  49.984942  8.409474  49.985673  8.424641
# 2  49.985613  8.424448  49.985538  8.424533
# 3  49.985528  8.424512  49.985679  8.424603
# 4  49.985679  8.424603  49.985636  8.424570

# %%
berlin_set.describe()
# Out:
#             b_number       orig_lat       orig_lng       dest_lat  \
# count  215081.000000  215081.000000  215081.000000  215081.000000
# mean    14654.294122      52.507602      13.397057      52.507384
# std      1072.039605       0.055461       0.481478       0.097934
# min     13001.000000      43.731304    -134.419963      14.465623
# 25%     13844.000000      52.494602      13.374192      52.494602
# 50%     14633.000000      52.507288      13.404928      52.507251
# 75%     15264.000000      52.520884      13.431451      52.520927
# max     99909.000000      58.304993      16.311548      53.559461
#
#             dest_lng
# count  215081.000000
# mean       13.398326
# std         0.429115
# min      -103.227823
# 25%        13.373811
# 50%        13.405409
# 75%        13.431698
# max       121.007462

# %%
frankfurt_set.describe()
# Out:
#            b_number      orig_lat      orig_lng      dest_lat      dest_lng
# count  20062.000000  20062.000000  20062.000000  20062.000000  20062.000000
# mean   38425.378676     50.116503      8.663449     50.116166      8.663158
# std     1508.156006      0.046574      0.348031      0.046621      0.348072
# min    11420.000000     48.353926     -3.240663     48.353926     -3.240663
# 25%    38165.000000     50.107599      8.663165     50.107599      8.660891
# 50%    38400.000000     50.114852      8.674521     50.114370      8.674521
# 75%    38698.000000     50.123192      8.690094     50.122879      8.689225
# max    91229.000000     51.525284     11.789030     51.525284     11.789030

# %%
berlin_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215081 entries, 0 to 215080
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   day            215081 non-null  object
#  1   time           215081 non-null  object
#  2   b_number       215081 non-null  int64
#  3   city           215081 non-null  object
#  4   trip_duration  215081 non-null  object
#  5   orig_lat       215081 non-null  float64
#  6   orig_lng       215081 non-null  float64
#  7   dest_lat       215081 non-null  float64
#  8   dest_lng       215081 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 14.8+ MB

# %% [markdown]
# ### Assumption:
# This gives us the information that the berlin dataset has no null inputs. This means we do not have missing numerical data.

# %%
frankfurt_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20062 entries, 0 to 20061
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            20062 non-null  object
#  1   time           20062 non-null  object
#  2   b_number       20062 non-null  int64
#  3   city           20062 non-null  object
#  4   trip_duration  20062 non-null  object
#  5   orig_lat       20062 non-null  float64
#  6   orig_lng       20062 non-null  float64
#  7   dest_lat       20062 non-null  float64
#  8   dest_lng       20062 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Assumption:
# This gives us the information that the frankfurt dataset has no null inputs. This means we do not have missing numerical data.

# %%
frankfurt_set["b_number"].describe()
# Out:
# count    20062.000000
# mean     38425.378676
# std       1508.156006
# min      11420.000000
# 25%      38165.000000
# 50%      38400.000000
# 75%      38698.000000
# max      91229.000000
# Name: b_number, dtype: float64

# %%
berlin_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215081 entries, 0 to 215080
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   day            215081 non-null  object
#  1   time           215081 non-null  object
#  2   b_number       215081 non-null  int64
#  3   city           215081 non-null  object
#  4   trip_duration  215081 non-null  object
#  5   orig_lat       215081 non-null  float64
#  6   orig_lng       215081 non-null  float64
#  7   dest_lat       215081 non-null  float64
#  8   dest_lng       215081 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 14.8+ MB

# %%
frankfurt_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20062 entries, 0 to 20061
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            20062 non-null  object
#  1   time           20062 non-null  object
#  2   b_number       20062 non-null  int64
#  3   city           20062 non-null  object
#  4   trip_duration  20062 non-null  object
#  5   orig_lat       20062 non-null  float64
#  6   orig_lng       20062 non-null  float64
#  7   dest_lat       20062 non-null  float64
#  8   dest_lng       20062 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
berlin_set.max()
# Out:
# day                             2019-06-30
# time                              23:58:00
# b_number                             99909
# city                                berlin
# trip_duration    0 days 02:59:00.000000000
# orig_lat                            58.305
# orig_lng                           16.3115
# dest_lat                           53.5595
# dest_lng                           121.007
# dtype: object

# %%
berlin_set.day.min()
# Out:
# '2019-02-01'

# %%
berlin_set.day.max()
# Out:
# '2019-06-30'

# %%
frankfurt_set.day.min()
# Out:
# '2019-02-01'

# %%
frankfurt_set.day.max()
# Out:
# '2019-06-30'

# %%
berlin_set["trip_duration"].min()
# Out:
# '0 days 00:03:00.000000000'

# %%
frankfurt_set.max()
# Out:
# day                             2019-06-30
# time                              23:58:00
# b_number                             91229
# city                             frankfurt
# trip_duration    0 days 02:59:00.000000000
# orig_lat                           51.5253
# orig_lng                            11.789
# dest_lat                           51.5253
# dest_lng                            11.789
# dtype: object

# %%
berlin_set.notnull()
# Out:
#          day  time  b_number  city  trip_duration  orig_lat  orig_lng  \
# 0       True  True      True  True           True      True      True
# 1       True  True      True  True           True      True      True
# 2       True  True      True  True           True      True      True
# 3       True  True      True  True           True      True      True
# 4       True  True      True  True           True      True      True
# ...      ...   ...       ...   ...            ...       ...       ...
# 215076  True  True      True  True           True      True      True
# 215077  True  True      True  True           True      True      True
# 215078  True  True      True  True           True      True      True
# 215079  True  True      True  True           True      True      True
# 215080  True  True      True  True           True      True      True
#
#         dest_lat  dest_lng
# 0           True      True
# 1           True      True
# 2           True      True
# ...

# %%
berlin_set.dropna(axis=0, inplace=False)
# Out:
#                day      time  b_number    city              trip_duration  \
# 0       2019-02-16  14:53:00     13001  berlin  0 days 00:21:00.000000000
# 1       2019-02-16  17:22:00     13001  berlin  0 days 00:27:00.000000000
# 2       2019-02-16  23:29:00     13001  berlin  0 days 00:22:00.000000000
# 3       2019-02-18  17:49:00     13001  berlin  0 days 00:15:00.000000000
# 4       2019-02-19  13:08:00     13001  berlin  0 days 00:09:00.000000000
# ...            ...       ...       ...     ...                        ...
# 215076  2019-05-13  09:57:00     30186  berlin  0 days 00:13:00.000000000
# 215077  2019-04-01  16:20:00     33140  berlin  0 days 00:50:00.000000000
# 215078  2019-05-10  10:59:00     38671  berlin  0 days 00:05:00.000000000
# 215079  2019-06-18  19:21:00     99851  berlin  0 days 00:03:00.000000000
# 215080  2019-06-19  15:43:00     99909  berlin  0 days 00:04:00.000000000
#
#          orig_lat   orig_lng   dest_lat   dest_lng
# ...

# %%
frankfurt_set.dropna(axis=0, inplace=False)
# Out:
#               day      time  b_number       city              trip_duration  \
# 0      2019-06-25  21:51:00     11420  frankfurt  0 days 00:07:00.000000000
# 1      2019-06-26  06:33:00     11420  frankfurt  0 days 00:14:00.000000000
# 2      2019-06-27  13:20:00     11420  frankfurt  0 days 00:07:00.000000000
# 3      2019-06-27  13:30:00     11420  frankfurt  0 days 00:04:00.000000000
# 4      2019-06-27  13:59:00     11420  frankfurt  0 days 00:09:00.000000000
# ...           ...       ...       ...        ...                        ...
# 20057  2019-05-07  09:36:00     91229  frankfurt  0 days 02:12:00.000000000
# 20058  2019-05-07  12:00:00     91229  frankfurt  0 days 00:11:00.000000000
# 20059  2019-05-07  14:04:00     91229  frankfurt  0 days 00:16:00.000000000
# 20060  2019-05-07  19:54:00     91229  frankfurt  0 days 00:10:00.000000000
# 20061  2019-05-08  04:17:00     91229  frankfurt  0 days 00:08:00.000000000
#
#         orig_lat  orig_lng   dest_lat  dest_lng
# ...

# %%
len(berlin_set)
# Out:
# 215081

# %%
len(frankfurt_set)
# Out:
# 20062

# %%
berlin_set_clean = berlin_set.dropna(axis=0)

# %%
frankfurt_set_clean = frankfurt_set.dropna(axis=0)

# %%
len(frankfurt_set_clean)
# Out:
# 20062

# %%
berlin_groups_time = berlin_set.groupby("time").mean()

# %%
berlin_groups_time
# Out:
#               b_number   orig_lat   orig_lng   dest_lat   dest_lng
# time
# 00:00:00  14823.000000  52.509153  13.400277  52.510011  13.399013
# 00:01:00  14764.145833  52.506596  13.413542  52.504770  13.411848
# 00:02:00  14799.863636  52.506570  13.408669  52.504924  13.404694
# 00:03:00  14390.750000  52.507414  13.408593  52.506248  13.399909
# 00:04:00  14575.660000  52.505127  13.420601  52.505247  13.411983
# ...                ...        ...        ...        ...        ...
# 23:54:00  14705.960784  52.503972  13.413665  52.504910  13.412602
# 23:55:00  14633.533333  52.507682  13.408982  52.510327  13.409330
# 23:56:00  14771.695652  52.504029  13.410360  52.507703  13.402140
# 23:57:00  14667.512821  52.502815  13.414464  52.503635  13.415740
# 23:58:00  14786.698113  52.502310  13.412757  52.505228  13.416110
#
# [1439 rows x 5 columns]

# %%
berlin_groups_bike = berlin_set.groupby("b_number").mean()

# %%
berlin_groups_bike
# Out:
#            orig_lat   orig_lng   dest_lat   dest_lng
# b_number
# 13001     52.506684  13.394909  52.507259  13.390498
# 13002     52.500879  13.399533  52.501519  13.400602
# 13005     52.503905  13.378970  52.504121  13.377603
# 13006     52.508452  13.375924  52.507436  13.376807
# 13007     52.505161  13.400469  52.504752  13.400070
# ...             ...        ...        ...        ...
# 30186     52.534774  13.346862  52.534924  13.347056
# 33140     52.507288  13.333964  52.505247  13.327885
# 38671     50.813178   8.775800  50.814100   8.770868
# 99851     52.494436  13.379319  52.497192  13.380079
# 99909     52.535013  13.347290  52.534947  13.347106
#
# [2406 rows x 4 columns]

# %%
berlin_groups_duration = berlin_set.groupby("trip_duration").mean()

# %%
berlin_groups_duration
# Out:
#                                b_number   orig_lat   orig_lng   dest_lat  \
# trip_duration
# 0 days 00:03:00.000000000  14679.300495  52.508689  13.394693  52.508627
# 0 days 00:04:00.000000000  14666.044570  52.506683  13.394820  52.506699
# 0 days 00:05:00.000000000  14625.049508  52.505343  13.395337  52.505416
# 0 days 00:06:00.000000000  14659.103736  52.506650  13.397426  52.507074
# 0 days 00:07:00.000000000  14666.890970  52.507372  13.399564  52.507605
# ...                                 ...        ...        ...        ...
# 0 days 02:55:00.000000000  14537.689655  52.508189  13.397270  52.504927
# 0 days 02:56:00.000000000  14444.238938  52.508311  13.398029  52.505008
# 0 days 02:57:00.000000000  14731.353535  52.511476  13.399076  52.511459
# 0 days 02:58:00.000000000  14368.302083  52.508190  13.394651  52.506427
# 0 days 02:59:00.000000000  14532.946809  52.511153  13.392621  52.510784
#
#                             dest_lng
# trip_duration
# ...

# %%
berlin_set.groupby("trip_duration").describe()
# Out:
#                           b_number                                      \
#                              count          mean          std      min
# trip_duration
# 0 days 00:03:00.000000000   1817.0  14679.300495  2255.166040  13002.0
# 0 days 00:04:00.000000000   1952.0  14666.044570  2169.283854  13006.0
# 0 days 00:05:00.000000000   3353.0  14625.049508  1113.412787  13001.0
# 0 days 00:06:00.000000000   5032.0  14659.103736  1031.767527  13001.0
# 0 days 00:07:00.000000000   6833.0  14666.890970  1046.266293  13001.0
# ...                            ...           ...          ...      ...
# 0 days 02:55:00.000000000    116.0  14537.689655  1120.422920  13014.0
# 0 days 02:56:00.000000000    113.0  14444.238938  1052.161926  13015.0
# 0 days 02:57:00.000000000     99.0  14731.353535  1227.917669  13064.0
# 0 days 02:58:00.000000000     96.0  14368.302083   963.503357  13010.0
# 0 days 02:59:00.000000000     94.0  14532.946809  1113.820968  13056.0
#
# ...

# %%
berlin_set.groupby("trip_duration").describe().transpose()
# Out:
# trip_duration   0 days 00:03:00.000000000  0 days 00:04:00.000000000  \
# b_number count                1817.000000                1952.000000
#          mean                14679.300495               14666.044570
#          std                  2255.166040                2169.283854
#          min                 13002.000000               13006.000000
#          25%                 13850.000000               13844.000000
#          50%                 14640.000000               14620.000000
#          75%                 15232.000000               15234.250000
#          max                 99851.000000               99909.000000
# orig_lat count                1817.000000                1952.000000
#          mean                   52.508689                  52.506683
#          std                     0.019147                   0.030734
#          min                    52.398786                  52.398920
#          25%                    52.496097                  52.493467
# ...

# %%
plt.figure(figsize = (50,50))
plt.scatter(berlin_set["trip_duration"], berlin_set["time"])
plt.xlabel("Flower ID")
plt.ylabel("Trip duration")
plt.title("Petal length per iris flower")
plt.show()

# %%
duration = berlin_set["trip_duration"]
colors = ['r', 'g', 'b']
f = []

for due in duration:
    f.append(berlin_set[berlin_set["trip_duration"]==due]["time"])

# %%
plt.hist(x=f, color=colors, bins=20, histtype='barstacked', label=species, width=0.1)
plt.legend()
plt.show()
